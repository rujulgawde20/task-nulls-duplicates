# %%
import pandas as pd

# %%
df = pd.read_csv('task_nulls_duplicates.csv')

# %%
df.head()
# Out:
#    OrderID  CustomerName Product       City    Price  Quantity
# 0        1  Arjun Saxena   Mouse     Jaipur  1410.31       5.0
# 1        2  Yuvraj Kumar    Lamp  Bangalore   372.96       NaN
# 2        3   Diya Kapoor  Wallet    Kolkata  2897.80       6.0
# 3        4    Myra Joshi     NaN     Mumbai  2511.93       1.0
# 4        5   Anika Gupta  Wallet     Mumbai  2356.51       3.0

# %%
df.shape
# Out:
# (50, 6)

# %%
df.isnull().sum()
# Out:
# OrderID         0
# CustomerName    3
# Product         1
# City            2
# Price           1
# Quantity        2
# dtype: int64

# %%
total_missing = df.isnull().sum().sum()
total_cells = df.size

print(f"{total_missing} missing values out of {total_cells} total cells ({total_missing/total_cells*100:.1f}%)")
# Out:
# 9 missing values out of 300 total cells (3.0%)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     OrderID  CustomerName     Product       City    Price  Quantity
# 1         2  Yuvraj Kumar        Lamp  Bangalore   372.96       NaN
# 3         4    Myra Joshi         NaN     Mumbai  2511.93       1.0
# 5         6           NaN       Mouse       Pune  1956.85       4.0
# 12       13    Saanvi Rao    Backpack       Pune      NaN       1.0
# 17       18           NaN    Notebook  Hyderabad  2507.84       4.0
# 22       23    Aisha Shah         Pen        NaN   237.46       1.0
# 26       27   Kabir Singh  Headphones        NaN  1392.55       1.0
# 29       30           NaN  Headphones     Mumbai   161.65       6.0
# 35       36    Dev Chopra      Wallet     Jaipur  1377.52       NaN

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df.duplicated()]
# Out:
#     OrderID CustomerName     Product       City    Price  Quantity
# 45        5  Anika Gupta      Wallet     Mumbai  2356.51       3.0
# 46       16  Aarav Mehta  Headphones    Chennai  2993.92       1.0
# 47       29  Aditya Iyer       Mouse  Bangalore  1810.64       1.0

# %%
df.duplicated(
    subset=['CustomerName','Product','Price','Quantity']
).sum()
# Out:
# np.int64(5)

# %%
df[df.duplicated(
    subset=['CustomerName','Product','Price','Quantity'],
    keep=False
)]
# Out:
#     OrderID  CustomerName     Product       City    Price  Quantity
# 4         5   Anika Gupta      Wallet     Mumbai  2356.51       3.0
# 8         9    Dev Chopra         Pen    Chennai  1220.89       1.0
# 15       16   Aarav Mehta  Headphones    Chennai  2993.92       1.0
# 28       29   Aditya Iyer       Mouse  Bangalore  1810.64       1.0
# 33       34  Rudra Pillai    Notebook    Kolkata  1199.61       1.0
# 45        5   Anika Gupta      Wallet     Mumbai  2356.51       3.0
# 46       16   Aarav Mehta  Headphones    Chennai  2993.92       1.0
# 47       29   Aditya Iyer       Mouse  Bangalore  1810.64       1.0
# 48      200    Dev Chopra         Pen    Chennai  1220.89       1.0
# 49      201  Rudra Pillai    Notebook    Kolkata  1199.61       1.0
